# %% [markdown]
# ## Comments
# suppose you are writing a program and want your client which has no experience in python so you want to add some explantory line to make him understandant what you are writing in this case we will use comments
# Comments are `lines that begin with # or are between ''' ''' `

# %%
# hello world

# %%
'''
hello world
hi 
'''
# Out:
# '\nhello world\nhi \n'

# %%
'''
helo
'''
print("hi")
# Out:
# hi

# %% [markdown]
# ## Functions
# there are some `built in `functions in python thta are very udeful
# u call a function by writing its name and parenthesis and what u want the function on like this :

# %%
print('hello world')
# Out:
# hello world

# %%
print(type('hello world'))
# Out:
# <class 'str'>

# %% [markdown]
# # Variables
# ## variables are nothing but reserved meemory locations to store values . this means when u create a variable you reserve some space in your meemory

# %%
var = "hello"
print(var)
# Out:
# hello

# %% [markdown]
# #### the name you give to a variable is known as its identifier identifiers have rules which must be followed so that u dont get and error
#
# `Rule 1` - Thay cannot contain any special charecter except `_`n\
# `Rule 2` - Identifiers cannot start with numbersn\
# `Rule 3` - Numbers cannot be identifiersn\

# %%
s_g = 'hello'

# %%
var_1 = 'hello'

# %% [markdown]
# # Standard Data Types
# ## the way of saying what type of data it is
#
# ## `Mutable Data Types once that can change`

# %% [markdown]
# # 1. Lists
# Lists are a way of ` storing ordered sequences of strings , floats ,tuples and dictionaries `

# %%
lst = [1,2,3,'hello',1.2,[2,3,3],(2,3)]
print(lst)
# Out:
# [1, 2, 3, 'hello', 1.2, [2, 3, 3], (2, 3)]

# %% [markdown]
# ### SLicing and indexing
# ## ` Indexing`

# %%
print(lst[0])
# Out:
# 1

# %%
print(lst[3][0])
# Out:
# h

# %%
print(lst[-1][-1])
# Out:
# 3

# %% [markdown]
# ## `SLicing`

# %%
d = lst[1:5]
print(d)
# Out:
# [2, 3, 'hello', 1.2]

# %%
print(lst[1:1:2])
# Out:
# [2, 'hello']

# %%
print(lst[::2])
# Out:
# [1, 3, 1.2, (2, 3)]

# %%
print(lst[::-1])
# Out:
# [(2, 3), [2, 3, 3], 1.2, 'hello', 3, 2, 1]

# %% [markdown]
# # 2. Dictionaries

# %% [markdown]
# `key:value`

# %%
mydict = {'name':"sandy",'age':'16',"name":"doha"}

# %%
mydict['major'] = 'datascience'

# %%
print(mydict)
# Out:
# {'name': 'doha', 'age': '16'}

# %%
mydict['name']
# Out:
# 'sandy'

# %%
mydict['name'] = 'sandy'

# %%
mydict.keys()
# Out:
# dict_keys(['name', 'age', 'major'])

# %%
mydict.values()
# Out:
# dict_values(['sandy', '16', 'datascience'])

# %% [markdown]
# # 3. Sets (curly brackets,unique)

# %%
sets = {2,3,34,4,3}

# %%
print(sets)
# Out:
# {2, 3, 34, 4}

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-cbfdee2b7bc0> in <module>
# ----> 1 sets.append(2)
#
# AttributeError: 'set' object has no attribute 'append'

# %% [markdown]
# ## `Immutable Data Types once that cannot change`
#
# # Strings
# ### Strings are way of storing words or sentences they are written in double or single quotes

# %%
print('Hi')
s = ['s','d','sdff','ds','shello','_D','shs']
print(s)
# Out:
# Hi
# ['s', 'd', 'sdff', 'ds', 'shello', '_D', 'shs']

# %%
s = 'hello world'
print(s.upper())
print(s.lower())
print(s.title())
# Out:
# HELLO WORLD
# hello world
# Hello World

# %% [markdown]
# # Numeric Values
# # 1. Integers
# ### Integers are numbers without deciamal points and quotes

# %%
print(type(20))
print(type('20'))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# # 2. Floats
# ###  Integers are numbers with deciamal points and wihtout quotes

# %%
print(type(1.2))
s = 20.0
s = 10 + s
print(type(s))
# Out:
# <class 'float'>
# <class 'float'>

# %% [markdown]
# # 3. Tuples ()
# Same as lists but have curly brackets and are

# %%
s = (2,3,4,4,5)
s
# Out:
# (2, 3, 4, 4, 5)

# %%
s[1]
s[1] = 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-c5e8ad108176> in <module>
#       1 s[1]
# ----> 2 s[1] = 2
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Booleans
# ## True or False

# %%
20 == 10
# Out:
# False

# %%
20 == 20
# Out:
# True

# %% [markdown]
# # `Python Operators`
# ## Operators are used to perform operations on variables and values.
#
# ## Python divides the operators in the following groups:
#
# 1. Arithmetic operators
# 2. Assignment operators
# 3. Comparison operators
# 4. Logical operators
# 5. Identity operators
# 6. Membership operators
# 7. Bitwise operators

# %%
1 + 2
# Out:
# 3

# %%
1 - 2
# Out:
# -1

# %%
1 * 2
# Out:
# 2

# %%
1 / 2
# Out:
# 0.5

# %%
20 % 2
# Out:
# 0

# %%
20 // 9
# Out:
# 2

# %%
s = 5
s += 3
s *= 10
s /= 10
s //= 2

s
# Out:
# 4.0

# %%
1 > 2
# Out:
# False

# %%
1 == 2
# Out:
# False

# %%
1 >= 2
# Out:
# False

# %%
1 <= 8
# Out:
# True

# %% [markdown]
# and - both
# or - one
# not - if its true it will be false and viceversa

# %%
1 > 2 and 2 < 1
false and false
false and true
true and false
true 
true and true

# %%
1 > 2 or 2 > 1
true
true and false
false and true 
false
false and false

# %%
not 1 > 2

# %%
not 'hello' in 'hello world'

# %%
if 2 == 1 :
    s = True
elif 2 == 2 :
    s = 'Think about it'
else :
    s = False
print(s)

# %%
s = range(100)
print(type(s))

# %%
for number in s :
    print('number' + str(number))

# %%
str(1)
int('2')
float('2.0')
q = 2

# %%
while 2 == q :
    q -= 1

# %%
s = range(1,101)
lam = lambda x : 2 + x
lam
